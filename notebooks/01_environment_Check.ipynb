# %%
# ── Environment Check ──────────────────────────────────────
import sklearn
import xgboost
import shap
import lime
import torch
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns
import imblearn

print("=" * 50)
print("DISSERTATION PROJECT — ENVIRONMENT CHECK")
print("=" * 50)
print(f"Scikit-learn  : {sklearn.__version__}")
print(f"XGBoost       : {xgboost.__version__}")
print(f"SHAP          : {shap.__version__}")
print(f"PyTorch       : {torch.__version__}")
print(f"Pandas        : {pd.__version__}")
print(f"NumPy         : {np.__version__}")
print(f"Matplotlib    : {matplotlib.__version__}")
print(f"Seaborn       : {sns.__version__}")
print(f"Imbalanced    : {imblearn.__version__}")
print("=" * 50)
# Out:
# ==================================================
# DISSERTATION PROJECT — ENVIRONMENT CHECK
# ==================================================
# Scikit-learn  : 1.7.2
# XGBoost       : 3.2.0
# SHAP          : 0.49.1
# PyTorch       : 2.12.0+cpu
# Pandas        : 2.3.3
# NumPy         : 2.2.6
# Matplotlib    : 3.10.9
# Seaborn       : 0.13.2
# Imbalanced    : 0.14.2
# ==================================================
